# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('C:/Users/LENOVO/Downloads/fmcg_sales_marketing_profitability_2023_2025.csv')

# %%
df.shape
df.head(15)
df.info()
df.describe()
df.isnull().sum()
df.duplicated().sum()
df['Order_ID'].nunique()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18240 entries, 0 to 18239
# Data columns (total 27 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Order_ID             18240 non-null  object
#  1   Order_Date           18240 non-null  object
#  2   Year                 18240 non-null  int64
#  3   Quarter              18240 non-null  object
#  4   Month                18240 non-null  int64
#  5   Month_Name           18240 non-null  object
#  6   Region               18240 non-null  object
#  7   Country              18240 non-null  object
#  8   City                 18240 non-null  object
#  9   Sales_Person         18240 non-null  object
#  10  Customer_Type        18240 non-null  object
#  11  Sales_Channel        18240 non-null  object
#  12  Promotion_Type       18240 non-null  object
#  13  Product_Category     18240 non-null  object
#  14  Brand                18240 non-null  object
# ...

# %%
df.describe()
# Out:
#                Year         Month    Units_Sold  Unit_Price_USD  Discount_Pct  \
# count  18240.000000  18240.000000  18240.000000    18240.000000  18240.000000
# mean    2024.001590      6.519024    212.909759        4.467254     12.935771
# std        0.816752      3.467308    202.102318        1.949341      5.735972
# min     2023.000000      1.000000      5.000000        1.450000      0.000000
# 25%     2023.000000      3.000000     70.000000        3.020000      8.710000
# 50%     2024.000000      7.000000    139.000000        3.990000     12.690000
# 75%     2025.000000     10.000000    288.000000        5.440000     16.850000
# max     2025.000000     12.000000   1366.000000       12.740000     28.000000
#
#        Gross_Sales_USD  Marketing_Spend_USD      COGS_USD  Logistics_Cost_USD  \
# count     18240.000000         18240.000000  18240.000000        18240.000000
# mean        936.431746            85.741888    471.024278           54.031789
# ...

# %%
print(df['Marketing_Spend_USD'].sum())

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18240 entries, 0 to 18239
# Data columns (total 27 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Order_ID             18240 non-null  object
#  1   Order_Date           18240 non-null  object
#  2   Year                 18240 non-null  int64
#  3   Quarter              18240 non-null  object
#  4   Month                18240 non-null  int64
#  5   Month_Name           18240 non-null  object
#  6   Region               18240 non-null  object
#  7   Country              18240 non-null  object
#  8   City                 18240 non-null  object
#  9   Sales_Person         18240 non-null  object
#  10  Customer_Type        18240 non-null  object
#  11  Sales_Channel        18240 non-null  object
#  12  Promotion_Type       18240 non-null  object
#  13  Product_Category     18240 non-null  object
#  14  Brand                18240 non-null  object
# ...

# %%
df.isnull().sum()
# Out:
# Order_ID               0
# Order_Date             0
# Year                   0
# Quarter                0
# Month                  0
# Month_Name             0
# Region                 0
# Country                0
# City                   0
# Sales_Person           0
# Customer_Type          0
# Sales_Channel          0
# Promotion_Type         0
# Product_Category       0
# Brand                  0
# Product_Name           0
# SKU                    0
# Units_Sold             0
# Unit_Price_USD         0
# Discount_Pct           0
# Gross_Sales_USD        0
# Marketing_Spend_USD    0
# COGS_USD               0
# Logistics_Cost_USD     0
# Net_Revenue_USD        0
# Profit_USD             0
# Profit_Margin_Pct      0
# dtype: int64

# %%
df.head(5)
# Out:
#            Order_ID  Order_Date  Year Quarter  Month Month_Name  \
# 0  FMCG-2025-000001  2025-09-26  2025      Q3      9  September
# 1  FMCG-2024-000002  2024-10-09  2024      Q4     10    October
# 2  FMCG-2024-000003  2024-07-06  2024      Q3      7       July
# 3  FMCG-2024-000004  2024-05-25  2024      Q2      5        May
# 4  FMCG-2023-000005  2023-08-10  2023      Q3      8     August
#
#           Region    Country         City   Sales_Person  ... Units_Sold  \
# 0        Oceania  Australia        Perth     Ethan Cole  ...         73
# 1           Asia      India       Mumbai     Meera Nair  ...         99
# 2  North America        USA  Los Angeles    Nina Booker  ...        361
# 3         Europe     France        Paris    Oliver Kent  ...        603
# 4         Europe     France         Lyon  Lucas Bennett  ...        113
#
#   Unit_Price_USD Discount_Pct Gross_Sales_USD Marketing_Spend_USD COGS_USD  \
# ...

# %%
df['Order_Date'] = pd.to_datetime(df['Order_Date'])
df.to_csv('cleaned_fmcg_data.csv', index=False)
